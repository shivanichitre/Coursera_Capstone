# %% [markdown]
# # IBM Capstone Project: The Battle of the Neighborhoods

# %% [markdown]
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# By- Shivani Chitre
#
# IBM Data Science Professional

# %% [markdown]
# # 1] Introduction/Business Problem

# %% [markdown]
# Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem.

# %% [markdown]
# ### Background:

# %% [markdown]
# If you take a look at the American Healthcare system the most frequently visited place is the Emergency Department. The first step people take is to visit the ER if a medical issue arises. There are certain other places along with the Emergency Department that a patient might visit given the extent of their health issue. There is the urgent care, minute clinics, and primary doctors. However, a primary doctor requires an appointment ahead of time.

# %% [markdown]
# Consider this situation, say that you are a new person or a tourist in a town and a medical situation emerges. What will you do? The first thing you will do is to google the nearest locations where you can find medical aid immediately. Usually in the US, Emergency room's average vist takes atleast a couple of hours. It is not pleasant to wait that long when you are unwell.

# %% [markdown]
# #### So what can you do?

# %% [markdown]
# ### Project Idea:

# %% [markdown]
# My idea for the Capstone Project is to show that when driven by venue and location data from FourSquare, people can readily get a list of health services in a given area and the wait time in each location.
# A high level approach is as follows:
#
# 1. The user decides on a city location [for my project I will use New York]
# 2. The ForeSquare website is scrapped for the top hospitals in the city
# 3. From this list of top hospitals the list is augmented with additional grographical data
# 4. Using this additional geographical data the top nearby hospitals are selected
# 5. The average waittime of all venues are obtained
# 6. A map is presented to the to the user showing the selected venues and waitime statistics of the locations.

# %% [markdown]
# #### Target Audience

# %% [markdown]
# This can help the users or even healthcare workers to be effecient and allocate patients to seek their medical needs proficiently. If the medical emergency is urgent they can pick which location to go to with the least average waiting period in theory.
#
# Based on this information it is possible that customers may prefer to stay in the area with good hospitals along with lower wait times. It is a good idea for older people to live in the vicinty of a hospital or patients with chronic illnesses.

# %% [markdown]
# # 2] Data

# %% [markdown]
# In this section, I will describe the data used to solve the problem as described previously.
#
# There are many data science aspect of this project including:
#
# - Data Acquisition
# - Data Cleansing
# - Data Analysis
# - Machine Learning
# - Prediction
#
# As noted below in the Further Development Section, this is a quite complex idea and in future we may need real time statistics to keep updating the capacity of hospital or a clinic while approaching this problem. However, as of now let's understand how to get the top medical care insitutions in a given area and look at their average history of wait time. The following scenario will be addressed:
#
# 1. I will convert address data into their equivalent latitude and longitude values.
# 2. For New york city neighborhood data, I will use wikipedia , https://en.wikipedia.org/wiki/Category:Districts of New York
# 3. I will use the Foursquare API to explore New York neighborhoods and to get venues in neighborhoods.
# 4. I will use the Foursquare API to get top locations and likes in neighborhoods.
# 5. I will use the k-means clustering and Agglomerative algorithms to complete clustering task
# 6. I will use the Folium library to visualize the neighborhoods, venues , clusters in New York
